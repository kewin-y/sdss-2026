# %% [markdown]
# # SDSS Datathon 2026

# %%
import numpy as np
import duckdb
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pl.read_excel("public_services_dataset.xlsx")
df.head()
# Out:
# shape: (5, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ OCCUPANCY ┆ LOCATION_ ┆ SECTOR    ┆ OVERNIGHT ┆ … ┆ ACTUAL_CA ┆ OCCUPIED_ ┆ UNAVAILAB ┆ OCCUPANC │
# │ _DATE     ┆ POSTAL_CO ┆ ---       ┆ _SERVICE_ ┆   ┆ PACITY    ┆ CAPACITY  ┆ LE_CAPACI ┆ Y_RATE   │
# │ ---       ┆ DE        ┆ str       ┆ TYPE      ┆   ┆ ---       ┆ ---       ┆ TY        ┆ ---      │
# │ date      ┆ ---       ┆           ┆ ---       ┆   ┆ i64       ┆ i64       ┆ ---       ┆ f64      │
# │           ┆ str       ┆           ┆ str       ┆   ┆           ┆           ┆ i64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2024-01-0 ┆ M9W1J1    ┆ Families  ┆ Motel/Hot ┆ … ┆ 149       ┆ 149       ┆ 1         ┆ 1.0      │
# │ 1         ┆           ┆           ┆ el        ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Shelter   ┆   ┆           ┆           ┆           ┆          │
# │ 2024-01-0 ┆ M9W1J1    ┆ Mixed     ┆ Motel/Hot ┆ … ┆ 57        ┆ 57        ┆ 0         ┆ 1.0      │
# │ 1         ┆           ┆ Adult     ┆ el        ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Shelter   ┆   ┆           ┆           ┆           ┆          │
# │ 2024-01-0 ┆ M5S2P1    ┆ Mixed     ┆ Shelter   ┆ … ┆ 8         ┆ 8         ┆ 0         ┆ 1.0      │
# │ 1         ┆           ┆ Adult     ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-01-0 ┆ M2J4R1    ┆ Families  ┆ Motel/Hot ┆ … ┆ 67        ┆ 67        ┆ 16        ┆ 1.0      │
# │ 1         ┆           ┆           ┆ el        ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Shelter   ┆   ┆           ┆           ┆           ┆          │
# │ 2024-01-0 ┆ M2J4R1    ┆ Families  ┆ Motel/Hot ┆ … ┆ 161       ┆ 161       ┆ 0         ┆ 1.0      │
# │ 1         ┆           ┆           ┆ el        ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Shelter   ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ## Average vs. Maximum of Occupancy Rates

# %%
# avg vs max rate grouped by sector 
duckdb.sql("""SELECT sector, AVG(occupancy_rate) AS avg_rate, MAX(occupancy_rate) AS max_rate, STDDEV_POP(occupancy_rate) AS standev
              FROM df 
              GROUP BY sector
              ORDER BY avg_rate""").show()

# avg vs max rate grouped by service type  
duckdb.sql("""SELECT overnight_service_type, AVG(occupancy_rate) AS avg_rate, MAX(occupancy_rate) AS max_rate
              FROM df 
              GROUP BY overnight_service_type
              ORDER BY avg_rate""").show()

# avg vs max rate grouped by program area 
duckdb.sql("""SELECT program_area, AVG(occupancy_rate) AS avg_rate, MAX(occupancy_rate) AS max_rate 
              FROM df 
              GROUP BY program_area
              ORDER BY avg_rate ASC""").show()

# avg vs max rate grouped by capacity type  
duckdb.sql("""SELECT capacity_type, AVG(occupancy_rate) AS avg_rate, MAX(occupancy_rate) AS max_rate
              FROM df 
              GROUP BY capacity_type
              ORDER BY avg_rate ASC""").show()
# Out:
# ┌─────────────┬────────────────────┬──────────────────┬─────────────────────┐
# │   SECTOR    │      avg_rate      │     max_rate     │       standev       │
# │   varchar   │       double       │      double      │       double        │
# ├─────────────┼────────────────────┼──────────────────┼─────────────────────┤
# │ Youth       │  0.943079101398137 │              1.0 │ 0.12115065293761902 │
# │ Mixed Adult │ 0.9718532392262458 │              1.0 │ 0.09957276272455251 │
# │ Men         │ 0.9760693757431431 │ 1.01470588235294 │ 0.08021408448026725 │
# │ Families    │ 0.9851799814896349 │              1.0 │ 0.06024979798886022 │
# │ Women       │ 0.9869279079753185 │ 1.01639344262295 │  0.0662470798170158 │
# └─────────────┴────────────────────┴──────────────────┴─────────────────────┘
#
# ┌────────────────────────────┬────────────────────┬──────────────────┐
# │   OVERNIGHT_SERVICE_TYPE   │      avg_rate      │     max_rate     │
# │          varchar           │       double       │      double      │
# ├────────────────────────────┼────────────────────┼──────────────────┤
# │ Surge site                 │ 0.7085235471599104 │              1.0 │
# │ Alternative Space Protocol │ 0.8081731407689139 │              1.0 │
# │ Warming Centre             │ 0.9044871848443918 │              1.0 │
# │ Top Bunk Contingency Space │ 0.9507385636915752 │              1.0 │
# │ Shelter                    │ 0.9723919773907523 │ 1.01639344262295 │
# │ 24-Hour Women's Drop-in    │ 0.9726955960652409 │              1.0 │
# │ Isolation/Recovery Site    │ 0.9802992735508074 │              1.0 │
# │ 24-Hour Respite Site       │ 0.9816041952278719 │ 1.01470588235294 │
# │ Motel/Hotel Shelter        │ 0.9935657777773906 │              1.0 │
# └────────────────────────────┴────────────────────┴──────────────────┘
#
# ┌────────────────────────────────────────────┬────────────────────┬──────────────────┐
# │                PROGRAM_AREA                │      avg_rate      │     max_rate     │
# │                  varchar                   │       double       │      double      │
# ├────────────────────────────────────────────┼────────────────────┼──────────────────┤
# │ Winter Programs                            │ 0.8720456723252376 │              1.0 │
# │ Temporary Refugee Response                 │  0.965915050011452 │              1.0 │
# │ Base Program - Refugee                     │ 0.9751759045399309 │              1.0 │
# │ Base Shelter and Overnight Services System │ 0.9756867200423306 │ 1.01639344262295 │
# │ Temporary Programs                         │ 0.9922959765042693 │              1.0 │
# └────────────────────────────────────────────┴────────────────────┴──────────────────┘
#
# ┌─────────────────────┬────────────────────┬──────────────────┐
# │    CAPACITY_TYPE    │      avg_rate      │     max_rate     │
# │       varchar       │       double       │      double      │
# ├─────────────────────┼────────────────────┼──────────────────┤
# │ Bed Based Capacity  │ 0.9646850848416236 │ 1.01639344262295 │
# │ Room Based Capacity │  0.992106881261012 │              1.0 │
# └─────────────────────┴────────────────────┴──────────────────┘

# %% [markdown]
# **Interpretation**
#
# Looking at the maximum rate of occupancies, we know that exceeding a rate of 1 means more people are in a room than the set capacity of that room. Summarizing the data, we can see that the men and women sectors, shelter and 24-hour repsite site service types, base shelter and overnight system program areas, and bed-based capacity capacity types all exceed an occupancy rate of 1.
#
# Connecting these key pieces of data together, we can say that homelessness resources with "broader" descriptions tend to experience higher levels of overpopulation. For example, the 24 hour drop-in for women has a maximum rate of 1, whereas the 24 hour respite site is a similar resource—but allows for any gender—exceeds a rate of 1.
#
# I suggest looking into how resources for those shelters are allocated and focusing on places that accept a wider group of people as they tend to exceed maximum capacity.
#
# ---
#
# Now I want to specifically analyze the information from the first table. We can see the average rates for youth is significantly lower compared to other sectors. Also the difference between the max and average is around 6%, giving more leeway for youth sectors to counteract shocks. It is fair to say that the youth sector may be the most resillient based on this data. Thus, we should focus on other sectors that are in a more dire situation.
#
# Looking at the top three highest averages, we can see which sectors are struggling the most: women, families, and men, with averages of approximatly 98.7%, 98.5%, and 97.6%, respectively. Note that the standard deviations are relatively low (0.06, 0.06, and 0.08), so we can conclude that occupancy rates for these sectors do not deviate from the average by a darastic amount. Since the men and women sectors have a maximum exceeding 1, let's focus on those sectors, specifically how many times each sector surpasses the breaking point of occupancy rate = 1.

# %%
# Counting how many times a row hits max rate grouped by sector  
duckdb.sql("""SELECT sector, occupancy_rate, occupancy_date
              FROM df
              WHERE occupancy_rate > 1 """).show()

#Total rows with sector = men 
duckdb.sql("""SELECT COUNT(sector) AS men_count
              FROM df
              WHERE sector = 'Men'""").show()

#Total rows with sector = women 
duckdb.sql("""SELECT COUNT(sector) AS women_count
              FROM df
              WHERE sector = 'Women'""").show()
        
#Total rows with sector = families  
duckdb.sql("""SELECT COUNT(sector) AS families_count
              FROM df
              WHERE sector = 'Families'""").show()
# Out:
# ┌─────────┬──────────────────┬────────────────┐
# │ SECTOR  │  OCCUPANCY_RATE  │ OCCUPANCY_DATE │
# │ varchar │      double      │      date      │
# ├─────────┼──────────────────┼────────────────┤
# │ Men     │ 1.01470588235294 │ 2024-08-08     │
# │ Men     │ 1.01470588235294 │ 2024-08-09     │
# │ Men     │ 1.01470588235294 │ 2024-08-10     │
# │ Men     │ 1.01470588235294 │ 2024-08-11     │
# │ Men     │ 1.01470588235294 │ 2024-08-12     │
# │ Men     │ 1.01408450704225 │ 2024-08-13     │
# │ Women   │ 1.01612903225806 │ 2025-06-21     │
# │ Women   │ 1.01639344262295 │ 2025-07-31     │
# └─────────┴──────────────────┴────────────────┘
#
# ┌───────────┐
# │ men_count │
# │   int64   │
# ├───────────┤
# │     25994 │
# └───────────┘
#
# ┌─────────────┐
# │ women_count │
# │    int64    │
# ├─────────────┤
# │       17784 │
# └─────────────┘
#
# ┌────────────────┐
# │ families_count │
# │     int64      │
# ├────────────────┤
# │          10393 │
# └────────────────┘

# %% [markdown]
# **Interpretation**
#
# We can see that men exceed an occupancy rate of 1 six times, all in the month of August 2024. For the women sector, a rate of 1 was exceeded only two times and both in 2025. Additionally, the number of rows with sectors for men is around 30% more than for women and around double the amount for family sectors. This indicates that the male homeless population has more shelters, but is exceeding the capacity more times than the women and family sectors. Although the women sector reaches a higher rate in magnitude, the frequency of shelters in the men's sector outweights that difference. For the family sector, it does not exceed a rate if 1 and seems to be floating above water for now.
#
# With that, I suggest finding ways to lower average occupancy rates for the men's and women's sector to decrease the frequency that the men sector over populates and give the women's sector more leeway when shocks occur, as the difference between the max and average rate for the women's sector is around 3.6% which is half of that of the youth sector.
#
# More specifically, I would suggest looking into why the men's sector exceeded the maximum more than any other sector and only in early to mid August of 2024. Some questions may be: Was there a policy change in August 2024 that effected the system's ability to handle a shock, leading to larger actual capacities? How can these shocks be counteracted?

# %% [markdown]
# ## Occupancy Rates Over Time

# %%
#filter the data to sector = men 
df_men = df.filter(pl.col('SECTOR') == 'Men')

#scatter plot for occupancy rates (of men) over time 
plt.figure(figsize=(10, 5))
plt.scatter(
    df_men['OCCUPANCY_DATE'].to_list(),
    df_men['OCCUPANCY_RATE'].to_list(),
    alpha=0.5,
    color='steelblue',
    s=10
)
plt.axhline(y=1.0, color='red', linestyle='--', label='Max Capacity (100%)')
plt.xlabel('Date')
plt.ylabel('Occupancy Rate')
plt.title('Toronto Men\'s Shelter Occupancy Rate Over Time')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#filter the data to sector = women 
df_women = df.filter(pl.col('SECTOR') == 'Women')

#scatter plot for occupancy rates (of women) over time 
plt.figure(figsize=(10, 5))
plt.scatter(
    df_women['OCCUPANCY_DATE'].to_list(),
    df_women['OCCUPANCY_RATE'].to_list(),
    alpha=0.5,
    color='steelblue',
    s=10
)
plt.axhline(y=1.0, color='red', linestyle='--', label='Max Capacity (100%)')
plt.xlabel('Date')
plt.ylabel('Occupancy Rate')
plt.title('Toronto Women\'s Shelter Occupancy Rate Over Time')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#filter the data to sector = families 
df_fam = df.filter(pl.col('SECTOR') == 'Families')

#scatter plot for occupancy rates (of women) over time 
plt.figure(figsize=(10, 5))
plt.scatter(
    df_fam['OCCUPANCY_DATE'].to_list(),
    df_fam['OCCUPANCY_RATE'].to_list(),
    alpha=0.5,
    color='steelblue',
    s=10
)
plt.axhline(y=1.0, color='red', linestyle='--', label='Max Capacity (100%)')
plt.xlabel('Date')
plt.ylabel('Occupancy Rate')
plt.title('Toronto Families\' Shelter Occupancy Rate Over Time')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation**
#
# As expected, the men and women sectors have higher occupancy rates, clustering towards a rate of 1. Some new insights include the unpredicatability of the men and women sectors shown by the variability of rates and the spread of all sectors changing in 2025.
#
# In 2025, all sector's rates seem to be spread throughout the graph, often well below the middle rate of 0.5. This indicates a shock has occured, bringing down occupation rates. I suggest looking into what the shock was and continuing to monitor the rates in 2026 to see the longivity and effectiveness of this shock. We will see clearly in the next section how occupancy rates of declined.
#
# Side note: Although rates reached lower magnitudes in 2025, my research shows that in 2018, around 8000 people in Toronto reported to be homeless, however in 2024 this number grew to over 15000. This growing trend paired with the housing crisis in Ontario may suggest that homelessness would increase in 2025, leading occupancy rates to increase. We see that is not the case here and it may be due to a bias or political skew in the data.
# Another article claims to be seeing a similar trend in an area of homeslessness: emcampment rates. The article says that encampments fell from 500 in 2024 to just under 200 in 2025. However advocates claim that the city is making homelessness 'less visible' by placing homeless people in emergency shelter, a short-term solution, to discourage them from living in public spaces. However, there is no concrete data on where these people go after leaving the emergency shelters.

# %% [markdown]
# ## Decline of Occupancy Rates

# %%
#Calculating average annual occupancy rate grouped by sectors 
df_yearly = df.with_columns(
    pl.col('OCCUPANCY_DATE').dt.year().alias('year')
).group_by(['SECTOR', 'year']).agg(
    pl.col('OCCUPANCY_RATE').mean().alias('avg_occupancy_rate')
).sort(['SECTOR', 'year'])

print(df_yearly)

#Calculating the change/growth rates of average occupancy per year grouped by sectors
df_change = df_yearly.with_columns(
    pl.col('avg_occupancy_rate').diff().over('SECTOR').alias('rate_change')
)

print(df_change)

#Graphing the average occupancy rates over time 
for sector in df_change['SECTOR'].unique().to_list():
    subset = df_change.filter(pl.col('SECTOR') == sector)
    plt.plot(subset['year'].to_list(), subset['avg_occupancy_rate'].to_list(), label=sector, marker='o')

plt.legend()
plt.title('Average Occupancy Rate by Sector Over Time')
plt.xlabel('Year')
plt.ylabel('Avg Occupancy Rate')
plt.show()
# Out:
# shape: (10, 3)
# ┌─────────────┬──────┬────────────────────┐
# │ SECTOR      ┆ year ┆ avg_occupancy_rate │
# │ ---         ┆ ---  ┆ ---                │
# │ str         ┆ i32  ┆ f64                │
# ╞═════════════╪══════╪════════════════════╡
# │ Families    ┆ 2024 ┆ 0.993982           │
# │ Families    ┆ 2025 ┆ 0.976167           │
# │ Men         ┆ 2024 ┆ 0.987638           │
# │ Men         ┆ 2025 ┆ 0.964686           │
# │ Mixed Adult ┆ 2024 ┆ 0.9876             │
# │ Mixed Adult ┆ 2025 ┆ 0.957132           │
# │ Women       ┆ 2024 ┆ 0.995919           │
# │ Women       ┆ 2025 ┆ 0.97831            │
# │ Youth       ┆ 2024 ┆ 0.952988           │
# │ Youth       ┆ 2025 ┆ 0.934567           │
# └─────────────┴──────┴────────────────────┘
# shape: (10, 4)
# ┌─────────────┬──────┬────────────────────┬─────────────┐
# │ SECTOR      ┆ year ┆ avg_occupancy_rate ┆ rate_change │
# │ ---         ┆ ---  ┆ ---                ┆ ---         │
# │ str         ┆ i32  ┆ f64                ┆ f64         │
# ╞═════════════╪══════╪════════════════════╪═════════════╡
# │ Families    ┆ 2024 ┆ 0.993982           ┆ null        │
# │ Families    ┆ 2025 ┆ 0.976167           ┆ -0.017816   │
# │ Men         ┆ 2024 ┆ 0.987638           ┆ null        │
# │ Men         ┆ 2025 ┆ 0.964686           ┆ -0.022952   │
# │ Mixed Adult ┆ 2024 ┆ 0.9876             ┆ null        │
# │ Mixed Adult ┆ 2025 ┆ 0.957132           ┆ -0.030468   │
# │ Women       ┆ 2024 ┆ 0.995919           ┆ null        │
# │ Women       ┆ 2025 ┆ 0.97831            ┆ -0.017609   │
# │ Youth       ┆ 2024 ┆ 0.952988           ┆ null        │
# │ Youth       ┆ 2025 ┆ 0.934567           ┆ -0.018421   │
# └─────────────┴──────┴────────────────────┴─────────────┘

# %% [markdown]
# It is more clear how the occupancy rates have decreased from 2024 to 2025 from some sort of shock, reguardless of the housing crisis and increased prices within the economy.

# %%
#calculating average actual capacity grouped by sector 

df_capacity = df.with_columns(
    pl.col('OCCUPANCY_DATE').dt.year().alias('year')
).group_by(['SECTOR', 'year']).agg(
    pl.col('ACTUAL_CAPACITY').mean().alias('avg_actual_capacity')
).sort(['SECTOR', 'year'])

print(df_capacity) 


df_growth = df_capacity.with_columns(
    pl.col('avg_actual_capacity').shift(1).over('SECTOR').alias('prev_year_capacity')
).with_columns(
    ((pl.col('avg_actual_capacity') - pl.col('prev_year_capacity')) / pl.col('prev_year_capacity') * 100).alias('growth_rate')
)

print(df_growth)

plt.figure(figsize=(12, 6))

for sector in df_capacity['SECTOR'].unique().to_list():
    subset = df_capacity.filter(pl.col('SECTOR') == sector)
    plt.plot(
        subset['year'].to_list(),
        subset['avg_actual_capacity'].to_list(),
        label=sector,
        marker='o'
    )

plt.xlabel('Year')
plt.ylabel('Average Actual Capacity')
plt.title('Average Actual Capacity Growth by Sector Per Year')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# shape: (10, 3)
# ┌─────────────┬──────┬─────────────────────┐
# │ SECTOR      ┆ year ┆ avg_actual_capacity │
# │ ---         ┆ ---  ┆ ---                 │
# │ str         ┆ i32  ┆ f64                 │
# ╞═════════════╪══════╪═════════════════════╡
# │ Families    ┆ 2024 ┆ 56.008368           │
# │ Families    ┆ 2025 ┆ 53.994742           │
# │ Men         ┆ 2024 ┆ 61.82524            │
# │ Men         ┆ 2025 ┆ 58.335979           │
# │ Mixed Adult ┆ 2024 ┆ 71.628002           │
# │ Mixed Adult ┆ 2025 ┆ 61.918112           │
# │ Women       ┆ 2024 ┆ 44.735983           │
# │ Women       ┆ 2025 ┆ 41.623899           │
# │ Youth       ┆ 2024 ┆ 30.309061           │
# │ Youth       ┆ 2025 ┆ 29.110244           │
# └─────────────┴──────┴─────────────────────┘
# shape: (10, 5)
# ┌─────────────┬──────┬─────────────────────┬────────────────────┬─────────────┐
# │ SECTOR      ┆ year ┆ avg_actual_capacity ┆ prev_year_capacity ┆ growth_rate │
# │ ---         ┆ ---  ┆ ---                 ┆ ---                ┆ ---         │
# │ str         ┆ i32  ┆ f64                 ┆ f64                ┆ f64         │
# ╞═════════════╪══════╪═════════════════════╪════════════════════╪═════════════╡
# │ Families    ┆ 2024 ┆ 56.008368           ┆ null               ┆ null        │
# │ Families    ┆ 2025 ┆ 53.994742           ┆ 56.008368          ┆ -3.595224   │
# │ Men         ┆ 2024 ┆ 61.82524            ┆ null               ┆ null        │
# │ Men         ┆ 2025 ┆ 58.335979           ┆ 61.82524           ┆ -5.643749   │
# │ Mixed Adult ┆ 2024 ┆ 71.628002           ┆ null               ┆ null        │
# │ Mixed Adult ┆ 2025 ┆ 61.918112           ┆ 71.628002          ┆ -13.555997  │
# │ Women       ┆ 2024 ┆ 44.735983           ┆ null               ┆ null        │
# │ Women       ┆ 2025 ┆ 41.623899           ┆ 44.735983          ┆ -6.956558   │
# │ Youth       ┆ 2024 ┆ 30.309061           ┆ null               ┆ null        │
# │ Youth       ┆ 2025 ┆ 29.110244           ┆ 30.309061          ┆ -3.955311   │
# └─────────────┴──────┴─────────────────────┴────────────────────┴─────────────┘

# %% [markdown]
# ## General Heatmap Analysis

# %% [markdown]
# ### Prepare Data
#
# - For temporal analysis: convert dates into seasons. i.e., drop `OCCUPANCY_DATE` column and replace it with seasons.
# - Drop `LOCATION_POSTAL_CODE` column; difficult to make sense of without API calls
# - Select numerical data for use in the model (K Means Clustering)

# %%
heatmap_df = df.with_columns(
    pl.col("OCCUPANCY_DATE").dt.month().alias("MONTH")
).with_columns(
    pl.when(pl.col("MONTH").is_in([12, 1, 2]))
      .then(pl.lit("Winter"))
      .when(pl.col("MONTH").is_in([3, 4, 5]))
      .then(pl.lit("Spring"))
      .when(pl.col("MONTH").is_in([6, 7, 8]))
      .then(pl.lit("Summer"))
      .otherwise(pl.lit("Fall"))
      .alias("SEASON")
).drop("MONTH").drop("OCCUPANCY_DATE").drop("LOCATION_POSTAL_CODE").filter(pl.col("PROGRAM_MODEL").is_not_null())

heatmap_df.head()
# Out:
# shape: (5, 10)
# ┌────────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬────────┐
# │ SECTOR     ┆ OVERNIGHT_ ┆ PROGRAM_M ┆ PROGRAM_A ┆ … ┆ OCCUPIED_ ┆ UNAVAILAB ┆ OCCUPANCY ┆ SEASON │
# │ ---        ┆ SERVICE_TY ┆ ODEL      ┆ REA       ┆   ┆ CAPACITY  ┆ LE_CAPACI ┆ _RATE     ┆ ---    │
# │ str        ┆ PE         ┆ ---       ┆ ---       ┆   ┆ ---       ┆ TY        ┆ ---       ┆ str    │
# │            ┆ ---        ┆ str       ┆ str       ┆   ┆ i64       ┆ ---       ┆ f64       ┆        │
# │            ┆ str        ┆           ┆           ┆   ┆           ┆ i64       ┆           ┆        │
# ╞════════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪════════╡
# │ Families   ┆ Motel/Hote ┆ Emergency ┆ Temporary ┆ … ┆ 149       ┆ 1         ┆ 1.0       ┆ Winter │
# │            ┆ l Shelter  ┆           ┆ Refugee   ┆   ┆           ┆           ┆           ┆        │
# │            ┆            ┆           ┆ Response  ┆   ┆           ┆           ┆           ┆        │
# │ Mixed      ┆ Motel/Hote ┆ Emergency ┆ Temporary ┆ … ┆ 57        ┆ 0         ┆ 1.0       ┆ Winter │
# │ Adult      ┆ l Shelter  ┆           ┆ Refugee   ┆   ┆           ┆           ┆           ┆        │
# │            ┆            ┆           ┆ Response  ┆   ┆           ┆           ┆           ┆        │
# │ Mixed      ┆ Shelter    ┆ Emergency ┆ Base      ┆ … ┆ 8         ┆ 0         ┆ 1.0       ┆ Winter │
# │ Adult      ┆            ┆           ┆ Program - ┆   ┆           ┆           ┆           ┆        │
# │            ┆            ┆           ┆ Refugee   ┆   ┆           ┆           ┆           ┆        │
# │ Families   ┆ Motel/Hote ┆ Emergency ┆ Temporary ┆ … ┆ 67        ┆ 16        ┆ 1.0       ┆ Winter │
# │            ┆ l Shelter  ┆           ┆ Programs  ┆   ┆           ┆           ┆           ┆        │
# │ Families   ┆ Motel/Hote ┆ Emergency ┆ Temporary ┆ … ┆ 161       ┆ 0         ┆ 1.0       ┆ Winter │
# │            ┆ l Shelter  ┆           ┆ Refugee   ┆   ┆           ┆           ┆           ┆        │
# │            ┆            ┆           ┆ Response  ┆   ┆           ┆           ┆           ┆        │
# └────────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴────────┘

# %%
# Omit OCCUPANCY_RATE; it is derived from other features

numerical_cols = ["ACTUAL_CAPACITY", "OCCUPIED_CAPACITY", "UNAVAILABLE_CAPACITY"]
numerical_df = heatmap_df.select(pl.col(numerical_cols))
numerical_df.head()
# Out:
# shape: (5, 3)
# ┌─────────────────┬───────────────────┬──────────────────────┐
# │ ACTUAL_CAPACITY ┆ OCCUPIED_CAPACITY ┆ UNAVAILABLE_CAPACITY │
# │ ---             ┆ ---               ┆ ---                  │
# │ i64             ┆ i64               ┆ i64                  │
# ╞═════════════════╪═══════════════════╪══════════════════════╡
# │ 149             ┆ 149               ┆ 1                    │
# │ 57              ┆ 57                ┆ 0                    │
# │ 8               ┆ 8                 ┆ 0                    │
# │ 67              ┆ 67                ┆ 16                   │
# │ 161             ┆ 161               ┆ 0                    │
# └─────────────────┴───────────────────┴──────────────────────┘

# %% [markdown]
# ### Scale Dataset
#
# - Also convert data to `numpy`-compatible array for easy use with `sklearn`

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(numerical_df.to_numpy())

# %% [markdown]
# ### K Means Clustering
#
# - Perform K means clustering on numerical data
# - Motivation:
#     - K means clustering is an unsupervised model; can be used to categorize/find patterns in our numerical features

# %%
from sklearn.cluster import KMeans

NUM_CLUSTERS = 6

kmeans = KMeans(n_clusters=NUM_CLUSTERS, random_state=67).fit(X)
clusters = kmeans.labels_
cluster_df = heatmap_df.with_columns(
    pl.Series("CLUSTER_ID", clusters),
)

cluster_df.head()
# Out:
# shape: (5, 11)
# ┌────────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬────────┬───────────┐
# │ SECTOR     ┆ OVERNIGHT_ ┆ PROGRAM_M ┆ PROGRAM_A ┆ … ┆ UNAVAILAB ┆ OCCUPANCY ┆ SEASON ┆ CLUSTER_I │
# │ ---        ┆ SERVICE_TY ┆ ODEL      ┆ REA       ┆   ┆ LE_CAPACI ┆ _RATE     ┆ ---    ┆ D         │
# │ str        ┆ PE         ┆ ---       ┆ ---       ┆   ┆ TY        ┆ ---       ┆ str    ┆ ---       │
# │            ┆ ---        ┆ str       ┆ str       ┆   ┆ ---       ┆ f64       ┆        ┆ i32       │
# │            ┆ str        ┆           ┆           ┆   ┆ i64       ┆           ┆        ┆           │
# ╞════════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪════════╪═══════════╡
# │ Families   ┆ Motel/Hote ┆ Emergency ┆ Temporary ┆ … ┆ 1         ┆ 1.0       ┆ Winter ┆ 4         │
# │            ┆ l Shelter  ┆           ┆ Refugee   ┆   ┆           ┆           ┆        ┆           │
# │            ┆            ┆           ┆ Response  ┆   ┆           ┆           ┆        ┆           │
# │ Mixed      ┆ Motel/Hote ┆ Emergency ┆ Temporary ┆ … ┆ 0         ┆ 1.0       ┆ Winter ┆ 5         │
# │ Adult      ┆ l Shelter  ┆           ┆ Refugee   ┆   ┆           ┆           ┆        ┆           │
# │            ┆            ┆           ┆ Response  ┆   ┆           ┆           ┆        ┆           │
# │ Mixed      ┆ Shelter    ┆ Emergency ┆ Base      ┆ … ┆ 0         ┆ 1.0       ┆ Winter ┆ 0         │
# │ Adult      ┆            ┆           ┆ Program - ┆   ┆           ┆           ┆        ┆           │
# │            ┆            ┆           ┆ Refugee   ┆   ┆           ┆           ┆        ┆           │
# │ Families   ┆ Motel/Hote ┆ Emergency ┆ Temporary ┆ … ┆ 16        ┆ 1.0       ┆ Winter ┆ 1         │
# │            ┆ l Shelter  ┆           ┆ Programs  ┆   ┆           ┆           ┆        ┆           │
# │ Families   ┆ Motel/Hote ┆ Emergency ┆ Temporary ┆ … ┆ 0         ┆ 1.0       ┆ Winter ┆ 4         │
# │            ┆ l Shelter  ┆           ┆ Refugee   ┆   ┆           ┆           ┆        ┆           │
# │            ┆            ┆           ┆ Response  ┆   ┆           ┆           ┆        ┆           │
# └────────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴────────┴───────────┘

# %% [markdown]
# ### Interpret Clusters
#
# - Our kmeans model only considers the features `ACTUAL_CAPACITY`, `OCCUPIED_CAPACITY`, and `UNAVAILABLE_CAPACITY`
#     - We can get a rough idea of what these clusters represent by displaying the average of each feature (column) by `CLUSTER_ID`

# %%
cluster_aggregates_df = cluster_df.group_by(
    pl.col("CLUSTER_ID")
).agg(
    ACTUAL_CAPACITY_MEAN=pl.col("ACTUAL_CAPACITY").mean(),
    OCCUPIED_CAPACITY_MEAN=pl.col("OCCUPIED_CAPACITY").mean(),
    UNAVAILABLE_CAPACITY_MEAN=pl.col("UNAVAILABLE_CAPACITY").mean()
)

cluster_aggregates_df.head(n=NUM_CLUSTERS)
# Out:
# shape: (6, 4)
# ┌────────────┬──────────────────────┬────────────────────────┬───────────────────────────┐
# │ CLUSTER_ID ┆ ACTUAL_CAPACITY_MEAN ┆ OCCUPIED_CAPACITY_MEAN ┆ UNAVAILABLE_CAPACITY_MEAN │
# │ ---        ┆ ---                  ┆ ---                    ┆ ---                       │
# │ i32        ┆ f64                  ┆ f64                    ┆ f64                       │
# ╞════════════╪══════════════════════╪════════════════════════╪═══════════════════════════╡
# │ 5          ┆ 38.468869            ┆ 37.869653              ┆ 0.396053                  │
# │ 0          ┆ 13.065148            ┆ 12.174494              ┆ 1.618255                  │
# │ 2          ┆ 275.247371           ┆ 275.160707             ┆ 4.050063                  │
# │ 1          ┆ 76.762632            ┆ 75.988082              ┆ 2.422346                  │
# │ 4          ┆ 146.676562           ┆ 146.233241             ┆ 2.945849                  │
# │ 3          ┆ 59.760312            ┆ 59.025641              ┆ 87.917503                 │
# └────────────┴──────────────────────┴────────────────────────┴───────────────────────────┘

# %% [markdown]
# **Interpretation**
#
# - Clusters are distinguished by shelter capacity: **shelter capacity is the primary driver** for variance within numerical data
#
# **Areas for improvement**
#
# - Doing a K-means cluster on the data wasn't the best choice:
#     - Dataset contains mostly **categorical features**; a better model could have been utilized to incorporate all features
# - Categorizing the data by service capacity is a good starting point, but could have been done manually without an unsupervised model

# %%
# Since capacity size is the primary driver behind numerical data, we assign greater `CLUSTER_ID`s to
# greater `ACTUAL_CAPACITY_MEAN`

cluster_id_map = (
    cluster_aggregates_df
    .sort("ACTUAL_CAPACITY_MEAN")   
    .with_row_index("NEW_CLUSTER_ID")
    .select("CLUSTER_ID", "NEW_CLUSTER_ID")
)

cluster_df = (
    cluster_df
    .join(cluster_id_map, on="CLUSTER_ID", how="left")
    .with_columns(pl.col("NEW_CLUSTER_ID").alias("CLUSTER_ID"))
    .drop("NEW_CLUSTER_ID")
)

# Compute new aggregate dataframe for presentation
cluster_aggregates_df = (
    cluster_aggregates_df
    .join(cluster_id_map, on="CLUSTER_ID", how="left")
    .with_columns(pl.col("NEW_CLUSTER_ID").alias("CLUSTER_ID"))
    .drop("NEW_CLUSTER_ID")
)

cluster_aggregates_df.sort("CLUSTER_ID").head(NUM_CLUSTERS)
# Out:
# shape: (6, 4)
# ┌────────────┬──────────────────────┬────────────────────────┬───────────────────────────┐
# │ CLUSTER_ID ┆ ACTUAL_CAPACITY_MEAN ┆ OCCUPIED_CAPACITY_MEAN ┆ UNAVAILABLE_CAPACITY_MEAN │
# │ ---        ┆ ---                  ┆ ---                    ┆ ---                       │
# │ u32        ┆ f64                  ┆ f64                    ┆ f64                       │
# ╞════════════╪══════════════════════╪════════════════════════╪═══════════════════════════╡
# │ 0          ┆ 13.065148            ┆ 12.174494              ┆ 1.618255                  │
# │ 1          ┆ 38.468869            ┆ 37.869653              ┆ 0.396053                  │
# │ 2          ┆ 59.760312            ┆ 59.025641              ┆ 87.917503                 │
# │ 3          ┆ 76.762632            ┆ 75.988082              ┆ 2.422346                  │
# │ 4          ┆ 146.676562           ┆ 146.233241             ┆ 2.945849                  │
# │ 5          ┆ 275.247371           ┆ 275.160707             ┆ 4.050063                  │
# └────────────┴──────────────────────┴────────────────────────┴───────────────────────────┘

# %% [markdown]
# ### Counts by `CLUSTER_ID` and `OCCUPANCY_RATE`
#
# - For each categorical feature in the original dataset:
#     - Get the count that each value of the feature appears for each `CLUSTER_ID`
#         - Motivator: our clusters categorize shelter capacity, which, as mentioned before, is the primary driver for our numerical data
#         - We can visualize this data using a heatmap
#         - Repeat the same steps for `OCCUPANCY_RATE`: find out which occupancy rates dominate the heatmaps

# %%
def get_cluster_counts_df(feature):
    return (
         cluster_df.group_by(pl.col("CLUSTER_ID"), pl.col(feature))
        .agg(pl.len())
        .pivot(
            values="len", index="CLUSTER_ID", on=feature, aggregate_function="first"
        )
        .fill_null(0)
    )

# %%
def get_rates_counts_df(feature, bin_size=0.05, min_rate=0.6):
     return (
        cluster_df
        # Clip OCCUPANCY_RATE to min_rate
        .with_columns(
            pl.col("OCCUPANCY_RATE").clip(min_rate).alias("OCCUPANCY_CLIPPED")
        )
        # Bin the clipped occupancy rate
        .with_columns(
            (pl.col("OCCUPANCY_CLIPPED") // bin_size * bin_size).alias("OCCUPANCY_BIN")
        )
        .group_by(["OCCUPANCY_BIN", feature])
        .agg(pl.len())
        .pivot(
            values="len",
            index="OCCUPANCY_BIN",
            on=feature,
            aggregate_function="first"
        )
        .fill_null(0)
    )

# %%
def plot_heatmap(dataframe, feature, y="CLUSTER_ID", decimals=2):
    pdf = dataframe.sort(y).to_pandas().set_index(y)

    plt.figure(figsize=(10, 6))
    sns.heatmap(pdf, cmap="viridis")
    plt.xlabel(feature)
    plt.ylabel(y)
    plt.show()

# %%
categorical_features = ["SECTOR", "OVERNIGHT_SERVICE_TYPE", "PROGRAM_MODEL", "PROGRAM_AREA", "CAPACITY_TYPE", "SEASON"]

for feature in categorical_features:
    counts_df = get_cluster_counts_df(feature)
    plot_heatmap(counts_df, feature)

# %% [markdown]
# **Interpretation**
#
# - `CLUSTER_ID`s 0 and 1 dominate all heatmaps: most shelters have a small capacity (occupied & actual)
# - Most shelters used a bed-based capacity system
# - The Men and Mixed Adult sectors have the highest capacity (occupied & actual)
# - Heatmap is the most saturated in the winter: occupancy increases during the winter
# - Emergency services are the most in-demand
# - Shelter services are the most in-demand

# %%
for feature in categorical_features:
    counts_df = get_rates_counts_df(feature)
    plot_heatmap(counts_df, feature, y="OCCUPANCY_BIN")

# %% [markdown]
# **Interpretation**
#
# - The mixed adult sector has the highest occupancy rate

# %% [markdown]
# # Stress testing
#
# Guiding question:  Simulate operational scenarios, such as modest increases in demand or capacity, to explore how close the system is to critical thresholds.
#
# This section aims to test the shelter system's resilience in the event of increased demand within a region. It measures metrics in total remaining availability of beds/rooms and identifies most fragile sector and location as a result.

# %% [markdown]
# ## Part 0. Data preprocessing

# %%
# Add coordinates data into the data frame
import geoscript
orig_df = df.to_pandas()
df = geoscript.extract_geoinfo(orig_df)

# %% [markdown]
# ## Part 1. Defining a critical threshold and resilience score
#
# Define strain_score = min(((OCCUPIED_CAPACITY + UNAVAILABLE_CAPACITY)/ACTUAL CAPACITY), 1) where it is at a high operation strain level between 0.9-0.95, and at failure at 1.  strain_score is defined by geographical location.
#
# The below computes and show strain score by geographical neighbourhoods

# %%
import exploratory
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

df = exploratory.compute_strain(df)

# %%
# Plot the distribution of strain
exploratory.plot_strain_distribution(df)

# %% [markdown]
# We can analyse strain by region. Outputs below list out the regions with highest strain scores. There is also a heatmap to show the geographical distribution of strain scores. As we can see, shelters and overnight housing services in Toronto are generally at capacity.

# %%
# Analyse strain by region
geo_strain = exploratory.geo_strain(df)
# Out:
#    POSTAL_CODE_FSA  strain_score
# 10             M1T      1.000000
# 45             M6R      1.000000
# 1              M1B      0.999960
# 47             M8Y      0.999930
# 12             M2J      0.999844

# %%
# Plot strain heatmap
exploratory.plot_strain_heatmap(df)

# %%
# Analyse strain by sector
sectoral_strain = exploratory.sectoral_strain(df)
# Out:
#         SECTOR  strain_score
# 3        Women      0.990568
# 0     Families      0.989555
# 1          Men      0.975843
# 2  Mixed Adult      0.971111
# 4        Youth      0.950923

# %% [markdown]
# We thus define resilience score of the system as the proportion of strain_scores under 90%.

# %%
resilience = sum(df['is_resilient'])/len(df)
print(resilience)
# Out:
# 0.07065590659340659

# %% [markdown]
# Upon further exploratory analyses, we can see an increasing trend in resilience between 2024 and 2025.

# %%
"""
This code is adapted from Avery's work
"""

import plotly.express as px

# df['STRAIN'] = np.minimum(2,(df['OCCUPIED_CAPACITY']+df['UNAVAILABLE_CAPACITY'])/df['ACTUAL_CAPACITY'])

d = df.groupby('OCCUPANCY_DATE').agg(
    AVG_STRAIN = ('strain_score','mean'),
    RESILIENCE = ('strain_score', lambda x: (x < 0.9).sum() / len(x))
)

d = d.reset_index()

fig = px.line(d,
              x='OCCUPANCY_DATE',
              y='AVG_STRAIN',
              title='Average Strain (per day) Over Time')
fig.show()

fig2 = px.line(d,
              x='OCCUPANCY_DATE',
              y='RESILIENCE',
              title='RESILIENCE Over Time')
fig2.show()

# %%
# Filtering for 2025 data only
df['OCCUPANCY_DATE'] = pd.to_datetime(df['OCCUPANCY_DATE'])

df_2025 = df[df['OCCUPANCY_DATE'].dt.year == 2025].copy()

# %%
# Average resilience in 2025
print(exploratory.compute_resilience(df_2025))
# Out:
# 0.10151684882981622

# %% [markdown]
# We henceforth use 2025 data for our simulation.

# %% [markdown]
# ## Part 2. Simulating demand surge to test model resilience

# %% [markdown]
# In this section, we simulate demand surges by increasing occupied capacity from 5% to 400% current occupied capacity to find a breaking point of the system

# %%
import simulation

df_2025 = simulation.amplify_demand(df_2025)

# %%
simulation.plot_resilience_test(df_2025)

# %% [markdown]
# With an observed converge to 0 and given that we capped the occupied capacity at 100% the actual capacity, we can see the system breaks fast. A 15% increase results in a 40% decrease in resilience, and 30% demand surge would result in a 60% difference in the system's resilience, plunging it closer to 0.
#
# A 5-8% surge is at most what the system could take.

# %% [markdown]
# ## Part 3. Interpretation and Recommendations

# %% [markdown]
# The current system resilience score is 0.10 (10%). This means that only 1 in 10 facilities is currently operating with a safety buffer (defined as having a strain score below 0.9). The remaining 90% of the system is either at or near total capacity.
#
# The system exhibits high sensitivity to even minor increases in demand:
#
# * 5% Demand Surge (1.05 Multiplier): Resilience drops from 0.10 to 0.06. This represents a 40% loss of the system's remaining safety net.
#
# * 10% Demand Surge (1.10 Multiplier): Resilience further collapses to 0.04. This is a cumulative 60% decrease in resilience from the baseline.
#
# The data highlights that the strain is not distributed evenly. Sectors such as Women and Families are effectively at 0% resilience, as their baseline strain scores are already near 1.0. Geographically, specific FSAs (such as M1B, M1T, and M9C) show no ability to absorb new demand, creating "service deserts" where any additional need would likely result in immediate service denial.
#
# ### Interpretation of Stress Test Results
# The simulation demonstrates that the 2025 system is in a state of **extreme fragility**.
#
# * Fragility Metric: A minor 10% increase** in demand triggers a 60% collapse in system resilience (dropping from 0.10 to 0.04).
#
# * Breaking Point: The "cliff" occurs almost immediately, suggesting that the system is currently "borrowing" its operational stability from its last remaining buffers.
#
# * Risk Factor: Any unexpected surge—such as seasonal changes or economic shifts—exceeding 10% would result in total system saturation, leaving no resilient facilities available to take in new participants.
#
# ### Recommendation
# While the ideal solution is capacity expansion, it is also equally important to investigate the sources of high unavailable occupancy count. Some shelters have up to a 106:1 ratio in unavailable occupancy to available occupancy on certain days. Available physical space without actual capacity to act as shelters weakens the system, which significantly lower the chances of shelters responding adequately to demand surges.

# %% [markdown]
# # Relationships between features over time

# %%
orig_df.columns = ['OCCUPANCY_DATE','LOCATION_POSTAL_CODE','SECTOR','OVERNIGHT_SERVICE_TYPE','PROGRAM_MODEL',
                   'PROGRAM_AREA','CAPACITY_TYPE','ACTUAL_CAPACITY','OCCUPIED_CAPACITY','UNAVAILABLE_CAPACITY',
                   'OCCUPANCY_RATE']

# %%
df = orig_df.copy()

# Categorize into monthly buckets
df['OCCUPANCY_MONTH'] = df['OCCUPANCY_DATE'].dt.to_period('M').astype(str)

# %%
def fig_by_col(column):
  temp_df = df.groupby(['OCCUPANCY_MONTH', column]).agg(
      AVG_OCCUPANCY_RATE = ('OCCUPANCY_RATE','mean')
  )

  temp_df = temp_df.reset_index()

  fig = px.line(temp_df,
                x='OCCUPANCY_MONTH',
                y='AVG_OCCUPANCY_RATE',
                color=column,
                title='Average Occupancy Rate by ' + column + ' Over Time')
  return fig

# %%
fig_by_col('SECTOR').show()
fig_by_col('OVERNIGHT_SERVICE_TYPE').show()
fig_by_col('PROGRAM_MODEL').show()
fig_by_col('PROGRAM_AREA').show()
fig_by_col('CAPACITY_TYPE').show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09","2025-10","2025-11","2025-12"],"xaxis":"x","y":[0.9945487384832188,0.9953296960559943,0.996926340232143,0.9958688161937101,0.9953409190125452,0.9922682888189769,0.9933438072568854,0.9931695230324317,0.9957999602582512,0.9927667212902148,0.9919423422841186,0.9890846407026154,0.9848574911834747,0.9828311082532358,0.9797951797353306,0.9870444142994236,0.9870051052933473,0.9922394640722251,0.9920727769558698,0.9950511817108463,0.996639556279795,0.9956738487242658,0.9974291993158011,0.9985764950319576],"yaxis":"y","type":"scatter"},{"hovertemplate":"PROGRAM_AREA=Temporary Refugee Response\u003cbr\u003 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="62aea05c-3d63-44d1-b086-321709054d35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62aea05c-3d63-44d1-b086-321709054d35")) {                    Plotly.newPlot(                        "62aea05c-3d63-44d1-b086-321709054d35",                        [{"hovertemplate":"CAPACITY_TYPE=Bed Based Capacity\u003cbr\u003eOCCUPANCY_MONTH=%{x}\u003cbr\u003eAVG_OCCUPANCY_RATE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bed Based Capacity","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bed Based Capacity","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09","2025-10","2025-11","2025-12"],"xaxis":"x","y":[0.9770426550857244,0.9785008095594186,0.980817078869157,0.9824731528783498,0.9850317310376352,0.9801466640055035,0.9873054393015217,0.9893526284271064,0.9883176281449122,0.986261999730485,0.9756392372041716,0.9532524306750763,0.9523252742447937,0.9451122592463101,0.9535905773056098,0.961840809342782,0.9655570039308342,0.9464824791948326,0.9364990385280435,0.949173121578596,0.9668233839369085,0.9671092448761627,0.936912664262201,0.934809966107261],"yaxis":"y","type":"scatter"},{"hovertemplate":"CAPACITY_TYPE=Room Based Capacity\u003cbr\u003eOCCUPANCY_MONTH=%{x}\u003cbr\u003eAVG_OCCUPANCY_RATE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Room Based Capacity","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Room Based Capacity","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09","2025-10","2025-11","2025-12"],"xaxis":"x","y":[0.9941233306745433,0.994237533988769,0.9963370895094235,0.9958660312091376,0.9969246046707276,0.9940503971840718,0.9954006013763209,0.9952858673166891,0.9966682534322896,0.9913154889947294,0.9909188558712073,0.9877096663111452,0.9879952131432896,0.9847955920876166,0.9811174559582326,0.9874685086164944,0.9887116894122985,0.9920066865575694,0.9921505732416783,0.9929033164362528,0.9937732510139128,0.9961555431996285,0.9948445438196187,0.9896605473562017],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f ...

# %%
def fig2_by_col(column):

  temp_df = df.groupby(['LOCATION_POSTAL_CODE','SECTOR','OVERNIGHT_SERVICE_TYPE','PROGRAM_MODEL',
                   'PROGRAM_AREA','CAPACITY_TYPE']).agg(
      VAR_OCCUPANCY_RATE = ('OCCUPANCY_RATE','std')
  )

  temp_df = temp_df.reset_index()

  counts = temp_df.groupby(column).size()
  valid_columns = counts[counts >= 20].index
  filtered_temp_df = temp_df[temp_df[column].isin(valid_columns)]

  if filtered_temp_df.empty or len(filtered_temp_df[column].unique()) < 1:
      return px.scatter(title='Insufficient data')

  fig_hist = px.histogram(filtered_temp_df,
                        x='VAR_OCCUPANCY_RATE',
                        facet_col=column,
                        facet_col_wrap=3,
                        histnorm='percent', # Show proportions instead of counts
                        color=column,
                        title='Distribution of Occupancy Rate StdDev by ' + column)
  fig_hist.update_yaxes(matches='y')
  return fig_hist

# %%
fig2_by_col('SECTOR').show()
fig2_by_col('OVERNIGHT_SERVICE_TYPE').show()
fig2_by_col('PROGRAM_MODEL').show()
fig2_by_col('PROGRAM_AREA').show()
fig2_by_col('CAPACITY_TYPE').show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id
  valid_columns = counts[counts >= 20].index
  filtered_temp_df = temp_df[temp_df[column].isin(valid_columns)]

  if filtered_temp_df.empty or len(filtered_temp_df[column].unique()) < 1:
      return px.scatter(title='No data to display')

  fig_hist = px.histogram(filtered_temp_df,
                        x='VAR_UNAVAILABLE_RATIO',
                        facet_col=column,
                        facet_col_wrap=3,
                        histnorm='percent', # Show proportions instead of counts
                        color=column,
                        title='Distribution of UNAVAILABILITY RATIO Variance by ' + column)
  fig_hist.update_yaxes(matches='y')
  return fig_hist

# %%
fig3_by_col('SECTOR').show()
fig3_by_col('OVERNIGHT_SERVICE_TYPE').show()
fig3_by_col('PROGRAM_MODEL').show()
fig3_by_col('PROGRAM_AREA').show()
fig3_by_col('CAPACITY_TYPE').show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6ea62c2f-0662-494b-8f16-87343bcd2f81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ea62c2f-0662-494b-8f16-87343bcd2f81")) {                    Plotly.newPlot(                        "6ea62c2f-0662-494b-8f16-87343bcd2f81",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"percent","hovertemplate":"SECTOR=Mixed Adult\u003cbr\u003eVAR_UNAVAILABLE_RATIO=%{x}\u003cbr\u003epercent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mixed Adult","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Mixed Adult","offsetgroup":"Mixed Adult","orientation":"v","showlegend":true,"x":[0.0,0.10852658325963323,0.17889116280878825,0.01119344740657457,0.2632271949592679,0.06709096594264598,0.015366356201769774,0.0,0.007288551462784621,0.13947114817610876,0.0070330734164040076,0.3051230852979332,0.2893256620839012,0.24119648087455323,0.01431655591560975,0.009995025490081138,0.23013778973983032,0.16325742487282405,0.10249528361357921,0.011247851863896124,0.13616077489675743,0.2612341910836494,0.0,0.09201532058286796,0.0998044913909096,0.017312810898679743,0.10042377646960284,0.10998655667382207,0.013573172860252457,0.0032478516711163816,0.22024037347423506,0.240651728629019,0.11354368554549689,0.013449776553758726,0.0,0.0,0.2887260428280973,0.0,0.0093129124078869,0.13234368969870317,0.0,0.2419103090358487,0.008676731721368312,0.26018038954539846,0.00714088921683239,0.0035162900662249717,0.2551232761177615,0.10166571355506979,0.3637489623669953,0.1667441535078105,0.002568727516872467,0.06067812358322266,0.2411887521302516,0.0011332703815672546,0.031140577781747638],"xaxis":"x4","yaxis":"y4","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histnorm":"percent","hovertemplate":"SECTOR=Women\u003cbr\u003eVAR_UNAVAILABLE_RATIO=%{x}\u003cbr\u003epercent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Women","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Women","offsetgroup":"Women","orientation":"v","showlegend":true,"x":[0.019185188030512907,0.012533921563696255,0.0,0.0,0.0,0.2601352787220729,0.0778415745214248,0.10925729997291393,0.041251705021690684,0.027980156892061993,0.01125278635835208,0.0,0.0,0.0,0.05933908290969266,0.004524622916706659,0.13391328174032305,0.1888249014263875,0.0,0.006485665970548653,0.11570259289657202,0.0967936217158442,0.00654042285687444,0.0,0.0028255671433532366,0.012507187334545427,0.19276461339020393,0.0,0.0,0.23683273335783547,0.0030821946727304546],"xaxis":"x5","yaxis":"y5","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histnorm":"percent","hovertemplate":"SECTOR=Youth\u003cbr\u003eVAR_UNAVAILABLE_RATIO=%{x}\u003cbr\u003epercent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Youth","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"
total_data = df.groupby('OCCUPANCY_DATE').agg(
    TOTAL_OCCUPANCY = ('OCCUPIED_CAPACITY','sum'),
    TOTAL_CAPACITY = ('ACTUAL_CAPACITY','sum'),
    COUNT = ('SECTOR','count') # first argument can be anything
)

total_data = total_data.reset_index()
total_data['TOTAL_RATE'] = total_data['TOTAL_OCCUPANCY']/total_data['TOTAL_CAPACITY']

fig = px.line(total_data,
              x='OCCUPANCY_DATE',
              y=['TOTAL_CAPACITY','TOTAL_OCCUPANCY'],
              title='Total Occupancy and Capacity Over Time')
fig.show()

fig2 = px.line(total_data,
              x='OCCUPANCY_DATE',
              y='TOTAL_RATE',
              title='Aggregate Occupancy Rate Over Time')
fig2.show()

fig3 = px.line(total_data,
              x='OCCUPANCY_DATE',
              y='COUNT',
              title='Data Collection Over Time')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c3602c34-abac-47f3-92eb-2c6f0c5d74e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3602c34-abac-47f3-92eb-2c6f0c5d74e7")) {                    Plotly.newPlot(                        "c3602c34-abac-47f3-92eb-2c6f0c5d74e7",                        [{"hovertemplate":"variable=TOTAL_CAPACITY\u003cbr\u003eOCCUPANCY_DATE=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TOTAL_CAPACITY","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"TOTAL_CAPACITY","showlegend":true,"x":["2024-01-01T00:00:00","2024-01-02T00:00:00","2024-01-03T00:00:00","2024-01-04T00:00:00","2024-01-05T00:00:00","2024-01-06T00:00:00","2024-01-07T00:00:00","2024-01-08T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-11T00:00:00","2024-01-12T00:00:00","2024-01-13T00:00:00","2024-01-14T00:00:00","2024-01-15T00:00:00","2024-01-16T00:00:00","2024-01-17T00:00:00","2024-01-18T00:00:00","2024-01-19T00:00:00","2024-01-20T00:00:00","2024-01-21T00:00:00","2024-01-22T00:00:00","2024-01-23T00:00:00","2024-01-24T00:00:00","2024-01-25T00:00:00","2024-01-26T00:00:00","2024-01-27T00:00:00","2024-01-28T00:00:00","2024-01-29T00:00:00","2024-01-30T00:00:00","2024-01-31T00:00:00","2024-02-01T00:00:00","2024-02-02T00:00:00","2024-02-03T00:00:00","2024-02-04T00:00:00","2024-02-05T00:00:00","2024-02-06T00:00:00","2024-02-07T00:00:00","2024-02-08T00:00:00","2024-02-09T00:00:00","2024-02-10T00:00:00","2024-02-11T00:00:00","2024-02-12T00:00:00","2024-02-13T00:00:00","2024-02-14T00:00:00","2024-02-15T00:00:00","2024-02-16T00:00:00","2024-02-17T00:00:00","2024-02-18T00:00:00","2024-02-19T00:00:00","2024-02-20T00:00:00","2024-02-21T00:00:00","2024-02-22T00:00:00","2024-02-23T00:00:00","2024-02-24T00:00:00","2024-02-25T00:00:00","2024-02-26T00:00:00","2024-02-27T00:00:00","2024-02-28T00:00:00","2024-02-29T00:00:00","2024-03-01T00:00:00","2024-03-02T00:00:00","2024-03-03T00:00:00","2024-03-04T00:00:00","2024-03-05T00:00:00","2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="acfa0a64-4b25-40f4-84e3-4266c6f559dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("acfa0a64-4b25-40f4-84e3-4266c6f559dc")) {                    Plotly.newPlot(                        "acfa0a64-4b25-40f4-84e3-4266c6f559dc",                        [{"hovertemplate":"OCCUPANCY_DATE=%{x}\u003cbr\u003eTOTAL_RATE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01T00:00:00","2024-01-02T00:00:00","2024-01-03T00:00:00","2024-01-04T00:00:00","2024-01-05T00:00:00","2024-01-06T00:00:00","2024-01-07T00:00:00","2024-01-08T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-11T00:00:00","2024-01-12T00:00:00","2024-01-13T00:00:00","2024-01-14T00:00:00","2024-01-15T00:00:00","2024-01-16T00:00:00","2024-01-17T00:00:00","2024-01-18T00:00:00","2024-01-19T00:00:00","2024-01-20T00:00:00","2024-01-21T00:00:00","2024-01-22T00:00:00","2024-01-23T00:00:00","2024-01-24T00:00:00","2024-01-25T00:00:00","2024-01-26T00:00:00","2024-01-27T00:00:00","2024-01-28T00:00:00","2024-01-29T00:00:00","2024-01-30T00:00:00","2024-01-31T00:00:00","2024-02-01T00:00:00","2024-02-02T00:00:00","2024-02-03T00:00:00","2024-02-04T00:00:00","2024-02-05T00:00:00","2024-02-06T00:00:00","2024-02-07T00:00:00","2024-02-08T00:00:00","2024-02-09T00:00:00","2024-02-10T00:00:00","2024-02-11T00:00:00","2024-02-12T00:00:00","2024-02-13T00:00:00","2024-02-14T00:00:00","2024-02-15T00:00:00","2024-02-16T00:00:00","2024-02-17T00:00:00","2024-02-18T00:00:00","2024-02-19T00:00:00","2024-02-20T00:00:00","2024-02-21T00:00:00","2024-02-22T00:00:00","2024-02-23T00:00:00","2024-02-24T00:00:00","2024-02-25T00:00:00","2024-02-26T00:00:00","2024-02-27T00:00:00","2024-02-28T00:00:00","2024-02-29T00:00:00","2024-03-01T00:00:00","2024-03-02T00:00:00","2024-03-03T00:00:00","2024-03-04T00:00:00","2024-03-05T00:00:00","2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="03f77d75-8219-46c3-91af-c56b2ebdb9bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03f77d75-8219-46c3-91af-c56b2ebdb9bb")) {                    Plotly.newPlot(                        "03f77d75-8219-46c3-91af-c56b2ebdb9bb",                        [{"hovertemplate":"OCCUPANCY_DATE=%{x}\u003cbr\u003eCOUNT=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01T00:00:00","2024-01-02T00:00:00","2024-01-03T00:00:00","2024-01-04T00:00:00","2024-01-05T00:00:00","2024-01-06T00:00:00","2024-01-07T00:00:00","2024-01-08T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-11T00:00:00","2024-01-12T00:00:00","2024-01-13T00:00:00","2024-01-14T00:00:00","2024-01-15T00:00:00","2024-01-16T00:00:00","2024-01-17T00:00:00","2024-01-18T00:00:00","2024-01-19T00:00:00","2024-01-20T00:00:00","2024-01-21T00:00:00","2024-01-22T00:00:00","2024-01-23T00:00:00","2024-01-24T00:00:00","2024-01-25T00:00:00","2024-01-26T00:00:00","2024-01-27T00:00:00","2024-01-28T00:00:00","2024-01-29T00:00:00","2024-01-30T00:00:00","2024-01-31T00:00:00","2024-02-01T00:00:00","2024-02-02T00:00:00","2024-02-03T00:00:00","2024-02-04T00:00:00","2024-02-05T00:00:00","2024-02-06T00:00:00","2024-02-07T00:00:00","2024-02-08T00:00:00","2024-02-09T00:00:00","2024-02-10T00:00:00","2024-02-11T00:00:00","2024-02-12T00:00:00","2024-02-13T00:00:00","2024-02-14T00:00:00","2024-02-15T00:00:00","2024-02-16T00:00:00","2024-02-17T00:00:00","2024-02-18T00:00:00","2024-02-19T00:00:00","2024-02-20T00:00:00","2024-02-21T00:00:00","2024-02-22T00:00:00","2024-02-23T00:00:00","2024-02-24T00:00:00","2024-02-25T00:00:00","2024-02-26T00:00:00","2024-02-27T00:00:00","2024-02-28T00:00:00","2024-02-29T00:00:00","2024-03-01T00:00:00","2024-03-02T00:00:00","2024-03-03T00:00:00","2024-03-04T00:00:00","2024-03-05T00:00:00","2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-2 ...

# %%
data = df.groupby('OCCUPANCY_DATE').agg(
    OCCUPANCY_RATE_STD = ('OCCUPANCY_RATE','std'),
)

data = data.reset_index()

fig = px.line(data,
              x='OCCUPANCY_DATE',
              y='OCCUPANCY_RATE_STD',
              title='Uneven(?) Allocation of Resources Over Time')

# %%
df['STRAIN'] = np.minimum(2,(df['OCCUPIED_CAPACITY']+df['UNAVAILABLE_CAPACITY'])/df['ACTUAL_CAPACITY'])

d = df.groupby('OCCUPANCY_DATE').agg(
    AVG_STRAIN = ('STRAIN','mean'),
    RESILIENCE = ('STRAIN', lambda x: (x < 0.9).sum() / len(x))
)

d = d.reset_index()

fig = px.line(d,
              x='OCCUPANCY_DATE',
              y='AVG_STRAIN',
              title='Average Strain (per day) Over Time')
fig.show()

fig2 = px.line(d,
              x='OCCUPANCY_DATE',
              y='RESILIENCE',
              title='RESILIENCE Over Time')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5736a725-94c6-4980-a639-31f7b2ce2067" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5736a725-94c6-4980-a639-31f7b2ce2067")) {                    Plotly.newPlot(                        "5736a725-94c6-4980-a639-31f7b2ce2067",                        [{"hovertemplate":"OCCUPANCY_DATE=%{x}\u003cbr\u003eAVG_STRAIN=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01T00:00:00","2024-01-02T00:00:00","2024-01-03T00:00:00","2024-01-04T00:00:00","2024-01-05T00:00:00","2024-01-06T00:00:00","2024-01-07T00:00:00","2024-01-08T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-11T00:00:00","2024-01-12T00:00:00","2024-01-13T00:00:00","2024-01-14T00:00:00","2024-01-15T00:00:00","2024-01-16T00:00:00","2024-01-17T00:00:00","2024-01-18T00:00:00","2024-01-19T00:00:00","2024-01-20T00:00:00","2024-01-21T00:00:00","2024-01-22T00:00:00","2024-01-23T00:00:00","2024-01-24T00:00:00","2024-01-25T00:00:00","2024-01-26T00:00:00","2024-01-27T00:00:00","2024-01-28T00:00:00","2024-01-29T00:00:00","2024-01-30T00:00:00","2024-01-31T00:00:00","2024-02-01T00:00:00","2024-02-02T00:00:00","2024-02-03T00:00:00","2024-02-04T00:00:00","2024-02-05T00:00:00","2024-02-06T00:00:00","2024-02-07T00:00:00","2024-02-08T00:00:00","2024-02-09T00:00:00","2024-02-10T00:00:00","2024-02-11T00:00:00","2024-02-12T00:00:00","2024-02-13T00:00:00","2024-02-14T00:00:00","2024-02-15T00:00:00","2024-02-16T00:00:00","2024-02-17T00:00:00","2024-02-18T00:00:00","2024-02-19T00:00:00","2024-02-20T00:00:00","2024-02-21T00:00:00","2024-02-22T00:00:00","2024-02-23T00:00:00","2024-02-24T00:00:00","2024-02-25T00:00:00","2024-02-26T00:00:00","2024-02-27T00:00:00","2024-02-28T00:00:00","2024-02-29T00:00:00","2024-03-01T00:00:00","2024-03-02T00:00:00","2024-03-03T00:00:00","2024-03-04T00:00:00","2024-03-05T00:00:00","2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7b5ba9fa-bd67-463a-9194-4bf103c46fda" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b5ba9fa-bd67-463a-9194-4bf103c46fda")) {                    Plotly.newPlot(                        "7b5ba9fa-bd67-463a-9194-4bf103c46fda",                        [{"hovertemplate":"OCCUPANCY_DATE=%{x}\u003cbr\u003eRESILIENCE=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01T00:00:00","2024-01-02T00:00:00","2024-01-03T00:00:00","2024-01-04T00:00:00","2024-01-05T00:00:00","2024-01-06T00:00:00","2024-01-07T00:00:00","2024-01-08T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-11T00:00:00","2024-01-12T00:00:00","2024-01-13T00:00:00","2024-01-14T00:00:00","2024-01-15T00:00:00","2024-01-16T00:00:00","2024-01-17T00:00:00","2024-01-18T00:00:00","2024-01-19T00:00:00","2024-01-20T00:00:00","2024-01-21T00:00:00","2024-01-22T00:00:00","2024-01-23T00:00:00","2024-01-24T00:00:00","2024-01-25T00:00:00","2024-01-26T00:00:00","2024-01-27T00:00:00","2024-01-28T00:00:00","2024-01-29T00:00:00","2024-01-30T00:00:00","2024-01-31T00:00:00","2024-02-01T00:00:00","2024-02-02T00:00:00","2024-02-03T00:00:00","2024-02-04T00:00:00","2024-02-05T00:00:00","2024-02-06T00:00:00","2024-02-07T00:00:00","2024-02-08T00:00:00","2024-02-09T00:00:00","2024-02-10T00:00:00","2024-02-11T00:00:00","2024-02-12T00:00:00","2024-02-13T00:00:00","2024-02-14T00:00:00","2024-02-15T00:00:00","2024-02-16T00:00:00","2024-02-17T00:00:00","2024-02-18T00:00:00","2024-02-19T00:00:00","2024-02-20T00:00:00","2024-02-21T00:00:00","2024-02-22T00:00:00","2024-02-23T00:00:00","2024-02-24T00:00:00","2024-02-25T00:00:00","2024-02-26T00:00:00","2024-02-27T00:00:00","2024-02-28T00:00:00","2024-02-29T00:00:00","2024-03-01T00:00:00","2024-03-02T00:00:00","2024-03-03T00:00:00","2024-03-04T00:00:00","2024-03-05T00:00:00","2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024 ...

# %%
surge_data = df[df['OVERNIGHT_SERVICE_TYPE']=='Surge site'].copy()

surge_data = surge_data.groupby('OCCUPANCY_DATE').agg(
    TOTAL_OCCUPANCY = ('OCCUPIED_CAPACITY','sum'),
)

surge_data = surge_data.reset_index()

fig = px.line(surge_data,
              x='OCCUPANCY_DATE',
              y= 'TOTAL_OCCUPANCY',
              title='Total Occupancy of Surge Sites Over Time')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b1d6eade-8d0e-41c6-b5b0-c611f0dd25b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1d6eade-8d0e-41c6-b5b0-c611f0dd25b0")) {                    Plotly.newPlot(                        "b1d6eade-8d0e-41c6-b5b0-c611f0dd25b0",                        [{"hovertemplate":"OCCUPANCY_DATE=%{x}\u003cbr\u003eTOTAL_OCCUPANCY=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-12-21T00:00:00","2025-01-07T00:00:00","2025-01-08T00:00:00","2025-01-18T00:00:00","2025-01-19T00:00:00","2025-01-20T00:00:00","2025-01-21T00:00:00","2025-01-22T00:00:00","2025-01-23T00:00:00","2025-01-24T00:00:00","2025-01-25T00:00:00","2025-01-26T00:00:00","2025-01-27T00:00:00","2025-01-28T00:00:00","2025-01-29T00:00:00","2025-01-30T00:00:00","2025-01-31T00:00:00","2025-02-01T00:00:00","2025-02-02T00:00:00","2025-02-03T00:00:00","2025-02-04T00:00:00","2025-02-05T00:00:00","2025-02-06T00:00:00","2025-02-07T00:00:00","2025-02-08T00:00:00","2025-02-09T00:00:00","2025-02-10T00:00:00","2025-02-11T00:00:00","2025-02-12T00:00:00","2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-12-14T00:00:00","2025-12-31T00:00:00"],"xaxis":"x","y":[7,21,7,14,28,47,59,60,59,59,52,37,30,30,30,23,25,24,26,25,25,22,21,12,12,12,15,16,18,17,17,30,53,60,61,61,63,56,30,19,19,15,15,5,8,6,1,16,7],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e" ...

# %%
winter_data = df[df['PROGRAM_AREA']=='Winter Programs'].copy()

winter_data = winter_data.groupby('OCCUPANCY_DATE').agg(
    TOTAL_OCCUPANCY = ('OCCUPIED_CAPACITY','sum'),
)

winter_data = winter_data.reset_index()

fig = px.line(winter_data,
              x='OCCUPANCY_DATE',
              y= 'TOTAL_OCCUPANCY',
              title='Total Occupancy of Winter Programs Over Time')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f8cc3cb4-a0a0-494a-bfc5-a9049eb5aa88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8cc3cb4-a0a0-494a-bfc5-a9049eb5aa88")) {                    Plotly.newPlot(                        "f8cc3cb4-a0a0-494a-bfc5-a9049eb5aa88",                        [{"hovertemplate":"OCCUPANCY_DATE=%{x}\u003cbr\u003eTOTAL_OCCUPANCY=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01-01T00:00:00","2024-01-02T00:00:00","2024-01-03T00:00:00","2024-01-04T00:00:00","2024-01-05T00:00:00","2024-01-06T00:00:00","2024-01-07T00:00:00","2024-01-08T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-11T00:00:00","2024-01-12T00:00:00","2024-01-13T00:00:00","2024-01-14T00:00:00","2024-01-15T00:00:00","2024-01-16T00:00:00","2024-01-17T00:00:00","2024-01-18T00:00:00","2024-01-19T00:00:00","2024-01-20T00:00:00","2024-01-21T00:00:00","2024-01-22T00:00:00","2024-01-23T00:00:00","2024-01-24T00:00:00","2024-01-25T00:00:00","2024-01-26T00:00:00","2024-01-27T00:00:00","2024-01-28T00:00:00","2024-01-29T00:00:00","2024-01-30T00:00:00","2024-01-31T00:00:00","2024-02-01T00:00:00","2024-02-02T00:00:00","2024-02-03T00:00:00","2024-02-04T00:00:00","2024-02-05T00:00:00","2024-02-06T00:00:00","2024-02-07T00:00:00","2024-02-08T00:00:00","2024-02-09T00:00:00","2024-02-10T00:00:00","2024-02-11T00:00:00","2024-02-12T00:00:00","2024-02-13T00:00:00","2024-02-14T00:00:00","2024-02-15T00:00:00","2024-02-16T00:00:00","2024-02-17T00:00:00","2024-02-18T00:00:00","2024-02-19T00:00:00","2024-02-20T00:00:00","2024-02-21T00:00:00","2024-02-22T00:00:00","2024-02-23T00:00:00","2024-02-24T00:00:00","2024-02-25T00:00:00","2024-02-26T00:00:00","2024-02-27T00:00:00","2024-02-28T00:00:00","2024-02-29T00:00:00","2024-03-01T00:00:00","2024-03-02T00:00:00","2024-03-03T00:00:00","2024-03-04T00:00:00","2024-03-05T00:00:00","2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00", ...
